# %% [markdown]
# Working with data in Python

# %%
import pandas as pd
location = 'owid-covid-data.csv'

# %%
df = pd.read_csv(location)

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 177508      MNE    Europe   Montenegro  2023-03-27     289292.0        0.0
# 177509      MNE    Europe   Montenegro  2023-03-28     289292.0        0.0
# 177510      MNE    Europe   Montenegro  2023-03-29     289292.0        0.0
# 177511      MNE    Europe   Montenegro  2023-03-30     289292.0        0.0
# 177512      MNE    Europe   Montenegro     2023-03          NaN        NaN
#
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent    location        date  total_cases  new_cases  \
# 177508      MNE    Europe  Montenegro  2023-03-27     289292.0        0.0
# 177509      MNE    Europe  Montenegro  2023-03-28     289292.0        0.0
# 177510      MNE    Europe  Montenegro  2023-03-29     289292.0        0.0
# 177511      MNE    Europe  Montenegro  2023-03-30     289292.0        0.0
# 177512      MNE    Europe  Montenegro     2023-03          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 177508                 0.0        2808.0         0.0                  0.0
# 177509                 0.0        2808.0         0.0                  0.0
# 177510                 0.0        2808.0         0.0                  0.0
# 177511                 0.0        2808.0         0.0                  0.0
# 177512                 NaN           NaN         NaN                  NaN
#
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.624990e+05  1.743100e+05        1.735800e+05  1.525530e+05
# mean   4.753794e+06  9.848939e+03        9.887988e+03  5.823515e+04
# std    2.708338e+07  9.215591e+04        8.949980e+04  2.529559e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.626000e+03  0.000000e+00        2.286000e+00  1.220000e+02
# 50%    6.181500e+04  2.300000e+01        4.657100e+01  9.410000e+02
# 75%    5.153880e+05  5.510000e+02        6.435710e+02  9.080000e+03
# max    4.196805e+08  7.214500e+06        6.109993e+06  2.860865e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  174351.000000        173626.000000            162499.000000
# mean       75.530172            75.833559             90659.841874
# std       423.796369           414.736940            143227.538085
# min         0.000000             0.000000                 0.000000
# ...

# %%
df['total_cases']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 177508    289292.0
# 177509    289292.0
# 177510    289292.0
# 177511    289292.0
# 177512         NaN
# Name: total_cases, Length: 177513, dtype: float64

# %%
df['total_cases_per_million']
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#              ...
# 177508    461330.416
# 177509    461330.416
# 177510    461330.416
# 177511    461330.416
# 177512           NaN
# Name: total_cases_per_million, Length: 177513, dtype: float64

# %%
df['total_cases_per_million'] > 350000
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 177508     True
# 177509     True
# 177510     True
# 177511     True
# 177512    False
# Name: total_cases_per_million, Length: 177513, dtype: bool

# %%
Gr_total_cases_pm = df[df['total_cases_per_million']>350000]
print(Gr_total_cases_pm)
# Out:
#        iso_code continent    location        date  total_cases  new_cases  \
# 6754        AND    Europe     Andorra  2022-01-11      27983.0     1575.0
# 6755        AND    Europe     Andorra  2022-01-12      28542.0      559.0
# 6756        AND    Europe     Andorra  2022-01-13      28899.0      357.0
# 6757        AND    Europe     Andorra  2022-01-14      29888.0      989.0
# 6758        AND    Europe     Andorra  2022-01-15      29888.0        0.0
# ...         ...       ...         ...         ...          ...        ...
# 177507      MNE    Europe  Montenegro  2023-03-26     289292.0        0.0
# 177508      MNE    Europe  Montenegro  2023-03-27     289292.0        0.0
# 177509      MNE    Europe  Montenegro  2023-03-28     289292.0        0.0
# 177510      MNE    Europe  Montenegro  2023-03-29     289292.0        0.0
# 177511      MNE    Europe  Montenegro  2023-03-30     289292.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
print(df.head())
print("\nnum. total death cases per million: ", df.iloc[2,2])

print(df.tail())
print("\nnum. total death cases per million: ", df.iloc[2,2])
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
print(df.iloc[3:5,:])
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 3                                   NaN                          NaN
# ...

# %%
print(df.iloc[:,4:6])
# Out:
#         total_cases  new_cases
# 0               NaN        0.0
# 1               NaN        0.0
# 2               NaN        0.0
# 3               NaN        0.0
# 4               NaN        0.0
# ...             ...        ...
# 177508     289292.0        0.0
# 177509     289292.0        0.0
# 177510     289292.0        0.0
# 177511     289292.0        0.0
# 177512          NaN        NaN
#
# [177513 rows x 2 columns]
